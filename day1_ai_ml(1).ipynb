# %%
# Build a Simple Calculator
# Concepts Type Casting, Variable, Data Types, I/O functions
a = int(input("Enter first number: "))
b = int(input("Enter second number:"))

print("Addition is:", a+b)
print(f"Additionis:{a+b}")
print(f"Subtraction is: {a-b}")
print(f"Multiplication is: {a*b}")
print(f"Division is: {a/b}")
# Out:
# Enter first number: 10
# Enter second number:5
# Addition is: 15
# Additionis:15
# Subtraction is: 5
# Multiplication is: 50
# Division is: 2.0

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
dept = input("Enter your department:")

print(f"My name is {name}, age is {age} & the depertment is {dept}")
# Out:
# Enter your name:Priyadeep
# Enter your age:20
# Enter your department:ECE
# My name is Priyadeep, age is 20 & the depertment is ECE

# %%
# if-else-elif statement & Indentation
# lets find greatst among three numbers

a = int(input("enter a: "))
b=int(input("enter b: "))
c=int(input("enter c: "))

if a>b and a>c:
  print("a is the greatest")
elif b>a and b>c:
    print("b is the greatest")
else:
      print("c is the greatest")
# Out:
# enter a: 2
# enter b: 1
# enter c: 3
# c is the greatest
